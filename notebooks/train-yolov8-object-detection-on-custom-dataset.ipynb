# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="NHhuFKlyPkrWjsEaTzDa")
project = rf.workspace("mechzone").project("mechzone-eqkkl")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 80.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 90.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to mechzone-1 in yolov8:: 100%|██████████| 41264/41264 [00:21<00:00, 1888.66it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 62.4 MB/s eta 0:00:00
# ...

# %%
import os

# !curl -L "https://app.roboflow.com/ds/fPxwAj9dWh?key=Hd1iTchc59" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#  extracting: valid/images/ka_00574_png.rf.7497e294e5f6e94c694c14c487f2a2d3.jpg
#  extracting: valid/images/ka_00578_png.rf.8cf8725d4edc3e8eea2970655415abc2.jpg
#  extracting: valid/images/ka_00588_png.rf.a287a898a7178331e6900c754b74349b.jpg
#  extracting: valid/images/ka_00589_png.rf.9fb758338497c6d4a2189189947e87b3.jpg
#  extracting: valid/images/ka_00590_png.rf.e1f2bcec575b7149b5a1a11b4b3f9458.jpg
#  extracting: valid/images/ka_00593_png.rf.3a360b58f4f526a90f73a8f0381c9729.jpg
#  extracting: valid/images/ka_00607_png.rf.50b6f3326c7546fad13bd5c85de9f009.jpg
#  extracting: valid/images/ka_00609_png.rf.499fed7a358c610ece2a4f78b0fa6306.jpg
#  extracting: valid/images/ka_00612_png.rf.d9f40dfa85e25f63d52fdcffaf88b337.jpg
#  extracting: valid/images/ka_00613_png.rf.4cca0e2ea2c57faf9cdfd83c53a5a14a.jpg
#  extracting: valid/images/ka_00616_png.rf.3a4f7f6a5977ea9eac28bdf4ea36fa25.jpg
# ...

# %%
# Eğitim komutu
# !yolo train data=data.yaml model=yolov8n.pt epochs=50 imgsz=416 project=frank_ika name=v1
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
